# %% [markdown]
# <a href="https://colab.research.google.com/github/TrickyHickey/COMP593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a971b8b-ba85-4465-bfa3-0d3bb0328807" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a971b8b-ba85-4465-bfa3-0d3bb0328807">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
  id integer PRIMARY KEY NOT NULL, 
  user_id integer NOT NULL, 
  friend_id integer NOT NULL, 
  FOREIGN KEY (user_id) REFERENCES people (id), 
  FOREIGN KEY (friend_id) REFERENCES people (id)
);"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
from math import frexp
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range


myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()


addRelationshipQuery = """INSERT INTO relationships (user_id, friend_id) 
                          VALUES (?, ?);"""


for _ in range(1000):
  #Populate the arguments that will be used in the query
  user_id = randrange(1, 1001)

  friend_id = user_id
  while friend_id == user_id: 
    friend_id = randrange(1, 1001)

  args = (user_id, friend_id)
  #Execute the query
  myCursor.execute(addRelationshipQuery, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
from pprint import pprint 

myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()


#Complete the below query
query =  """SELECT people.name, COUNT(relationships.friend_id) FROM relationships 
            LEFT JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)

myConnection.close()


#fp = open('report.txt', mode='')

#for result in results:
  #You will want to write the results to the file pointer here.
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# [('John Doe', 1),
#  ('Reginald Richards', 1),
#  ('Kristopher Mullins', 1),
#  ('Kristin Walters', 1),
#  ('Alan Smith', 1),
#  ('Brittany Joseph', 2),
#  ('Christopher Matthews', 3),
#  ('Christopher Richards', 2),
#  ('Julie Chung', 3),
#  ('Glen Porter', 1),
#  ('Christopher Martinez', 1),
#  ('Kristen Campbell', 1),
#  ('Timothy Allen', 1),
#  ('Shelia Mcgee', 1),
#  ('Michelle Holt', 1),
#  ('Edwin Mcdaniel', 2),
#  ('Lori Williams', 1),
#  ('Amy Richardson', 2),
#  ('Ashley Duarte', 1),
#  ('Vanessa Harris', 2),
#  ('Anna Shaw', 1),
#  ('Mrs. Jennifer Harvey', 1),
#  ('Kathryn May', 1),
#  ('Mark Dickson', 1),
#  ('Tina Rodriguez', 1),
#  ('Jessica Dickson', 3),
#  ('Jasmine Ward', 1),
#  ('Tammy Lawson', 3),
#  ('Raymond Morgan', 1),
#  ('Connor Alexander', 1),
#  ('Samantha Owens', 1),
#  ('Stanley Freeman', 3),
#  ('Amy Bush', 2),
#  ('Melissa Bradford', 4),
#  ('Nicholas Wiggins', 3),
#  ('Robert Strickland', 1),
#  ('Stephanie Smith', 1),
#  ('Charles Walker', 2),
#  ('Emily Hudson', 1),
#  ('Thomas Martinez', 2),
#  ('Jacob Singleton', 2),
#  ('Andrew Cox', 1),
#  ('Chase Marshall', 1),
#  ('Brian Walsh', 3),
#  ('Kimberly Norman', 1),
#  ('Sharon Walters', 1),
#  ('Allison Fisher', 1),
#  ('Eric Hernandez Jr.', 1),
#  ('Michael Tucker', 2),
#  ('Matthew Owens', 1),
#  ('Stephen Jackson', 1),
#  ('Kenneth Lopez', 2),
#  ('Katherine Robinson', 2),
#  ('Jennifer Edwards', 1),
#  ('Justin Hernandez', 1),
#  ('Elizabeth Harris', 1),
#  ('Michael Cole', 2),
#  ('James Carter', 1),
#  ('Samuel Acosta', 2),
#  ('Amanda Jones', 1),
#  ('Dale Smith', 2),
#  ('Nancy Taylor', 1),
#  ('Vincent Harding', 2),
#  ('Gregory Evans', 1),
#  ('Ryan Krause', 1),
#  ('Lynn Nichols', 2),
#  ('Charles Smith', 1),
#  ('Timothy Hopkins', 1),
#  ('Joshua Torres', 1),
#  ('Robert Noble', 1),
#  ('Laura Soto', 1),
#  ('Margaret Friedman', 1),
#  ('Margaret Kaufman', 2),
#  ('Erin Hicks', 1),
#  ('Heather Gardner', 1),
#  ('Ms. Jennifer Martin', 1),
#  ('Mary Johnson', 1),
#  ('Rebekah Elliott PhD', 1),
#  ('Scott Ingram', 1),
#  ('Taylor Jones', 1),
#  ('Sean Garza', 1),
#  ('Jamie Williams', 1),
#  ('Mrs. Mary Brown DDS', 3),
#  ('Sandra Alexander', 1),
#  ('Hunter Walters', 1),
#  ('Alexander Campbell', 1),
#  ('Sara Higgins', 1),
#  ('Carol Sanchez', 1),
#  ('Cindy Avila', 1),
#  ('Sandra Lewis', 1),
#  ('Patricia Jones', 1),
#  ('Daniel Hudson', 1),
#  ('Bryan Warren', 1),
#  ('Jesse Rios', 3),
#  ('Chelsea Schneider', 1),
#  ('Johnathan Burke', 1),
#  ('Lori Fuentes', 1),
#  ('Samuel Davis', 2),
#  ('Dawn Lewis', 1),
#  ('Elizabeth Blanchard', 2),
#  ('Kathleen Floyd', 2),
#  ('Nicholas Bass', 1),
#  ('Mr. Austin Medina', 1),
#  ('Logan Craig', 2),
#  ('Angelica Williams', 2),
#  ('Dennis Anderson', 5),
#  ('Jeffrey Garcia', 2),
#  ('Anthony Cole', 2),
#  ('Molly Dunn', 2),
#  ('Sharon Maxwell', 1),
#  ('Angela Yu', 1),
#  ('Kelly Cowan DVM', 2),
#  ('Mrs. Amy Phillips PhD', 1),
#  ('Christopher Graham', 1),
#  ('Felicia Roberts', 1),
#  ('Robert Jones', 2),
#  ('Megan Gonzales', 3),
#  ('Kim Wright', 1),
#  ('Timothy Price', 1),
#  ('Donald Johnson', 1),
#  ('Melissa Lindsey', 1),
#  ('Reginald Cruz', 1),
#  ('Candice Williamson', 2),
#  ('Whitney Hernandez', 1),
#  ('Teresa Taylor', 2),
#  ('Jamie Mcclure', 4),
#  ('Kaitlyn Mcpherson', 1),
#  ('Alejandra Jones', 2),
#  ('Pamela Randolph', 2),
#  ('Patrick Ashley', 1),
#  ('Catherine Donaldson', 3),
#  ('Miss Bethany Reyes', 1),
#  ('Brittany Bennett', 3),
#  ('Nicholas Maynard', 1),
#  ('Stacy Douglas', 1),
#  ('Tommy Lindsey', 1),
#  ('Jason Henson', 2),
#  ('Cassandra Martinez', 1),
#  ('Kristopher Gomez', 2),
#  ('David Ramirez', 1),
#  ('Lisa Thomas', 1),
#  ('Karen Silva', 1),
#  ('Martin Berg', 1),
#  ('Rachel Chan', 1),
#  ('Colleen Hernandez', 2),
#  ('Timothy Duffy', 1),
#  ('Christina Murray', 1),
#  ('Andrew Mendoza', 1),
#  ('Joshua Harris', 2),
#  ('Timothy Rose', 2),
#  ('Anne Mcbride', 1),
#  ('Lisa Gilmore', 1),
#  ('Kari Miller', 2),
#  ('Emily Mclaughlin', 4),
#  ('Katherine Smith', 2),
#  ('Jacob Rose', 2),
#  ('Linda Fernandez', 1),
#  ('Ellen Schmidt', 3),
#  ('Jeremiah Bailey', 2),
#  ('Troy Gonzalez', 2),
#  ('Amy Vasquez', 1),
#  ('Philip Fox', 2),
#  ('Bradley Tran', 1),
#  ('Cassidy Howe', 3),
#  ('Leslie Perez', 1),
#  ('Michael Murphy', 3),
#  ('Jessica Holmes', 1),
#  ('Christopher Middleton', 1),
#  ('Barbara Stevenson', 1),
#  ('Bryan Kelley', 1),
#  ('Brittany French', 1),
#  ('Justin Sawyer', 1),
#  ('Catherine Torres', 2),
#  ('Dakota Olson', 1),
#  ('Matthew Good', 2),
#  ('Eric Schneider', 1),
#  ('Adam White', 3),
#  ('John Hernandez', 1),
#  ('Adam Taylor', 1),
#  ('Willie Nguyen', 1),
#  ('Karen Reynolds', 1),
#  ('David Cole', 1),
#  ('Robin Fuller', 1),
#  ('Keith Erickson', 1),
#  ('Andrew Mayer', 1),
#  ('Heather Morgan', 2),
#  ('Leonard Griffith', 1),
#  ('Theresa Peterson', 1),
#  ('Carla Oconnor', 1),
#  ('Diana Howard', 2),
#  ('Tiffany Taylor', 1),
#  ('Martin Austin', 1),
#  ('Jeffrey Le', 1),
#  ('Barbara Alvarado', 2),
#  ('Dustin Chan', 2),
#  ('Cheryl Rojas', 1),
#  ('Joshua Dominguez', 1),
#  ('Andrew Morgan', 2),
#  ('Anne Randolph', 2),
#  ('Johnny Evans', 3),
#  ('Emily Baker', 1),
#  ('John Fernandez', 1),
#  ('Jonathan Johnson', 1),
#  ('Dave Gutierrez', 1),
#  ('Erica Sandoval', 1),
#  ('Adam Cox', 1),
#  ('Joshua Mcdonald', 1),
#  ('Tracey Mcdonald', 1),
#  ('Jessica Miranda', 1),
#  ('Alexander Jones', 1),
#  ('April Wade', 1),
#  ('Hunter Johnson', 2),
#  ('David Mendoza', 1),
#  ('Latasha Williams', 3),
#  ('Jill Hester', 1),
#  ('Tamara Smith', 1),
#  ('Elizabeth Reid', 1),
#  ('Aaron Tate', 1),
#  ('Erin Warren', 1),
#  ('Katrina Salinas', 1),
#  ('Darius Brown', 2),
#  ('Zachary Ray', 3),
#  ('Sean Martinez', 1),
#  ('Timothy Brown', 5),
#  ('Ashley Gilbert', 2),
#  ('Stanley Hill', 2),
#  ('Joanne Fry', 3),
#  ('Victoria Logan', 1),
#  ('Heather West', 1),
#  ('Joseph Scott', 1),
#  ('Timothy Garcia', 2),
#  ('Katherine Gibson', 1),
#  ('Cassandra Adams', 1),
#  ('Nicholas Stone', 1),
#  ('Julia Anderson', 2),
#  ('Lisa Kelly', 3),
#  ('Javier Singh', 2),
#  ('Jesus Hendrix', 2),
#  ('Carol Turner', 1),
#  ('Daniel Reeves', 1),
#  ('Angel Harper', 3),
#  ('Stanley Mckinney', 1),
#  ('Christine Rose', 2),
#  ('Kristin French', 1),
#  ('John Allen', 1),
#  ('Scott Watson', 2),
#  ('Elizabeth Mullins', 1),
#  ('Jennifer Richardson', 2),
#  ('Julia Smith', 1),
#  ('Patrick Wood', 1),
#  ('Dwayne Murphy', 2),
#  ('Travis Pham', 1),
#  ('Diana Ford', 1),
#  ('Justin Bell', 1),
#  ('Heather Long', 1),
#  ('Tony Thompson', 1),
#  ('Jeffrey Shaffer', 2),
#  ('Jason Savage', 2),
#  ('Paula Hardy', 2),
#  ('David Murray', 4),
#  ('Jennifer Clements', 1),
#  ('Rodney Wilson', 2),
#  ('Michelle Johnson', 1),
#  ('Jessica Kane', 2),
#  ('Natalie Sweeney', 1),
#  ('Tanya Calderon', 2),
#  ('Mark Garcia', 2),
#  ('Stephanie Rangel', 1),
#  ('Rhonda Carlson', 1),
#  ('Steven Noble', 2),
#  ('Benjamin Black', 1),
#  ('Frank Robinson', 2),
#  ('Yolanda Peterson', 2),
#  ('Elizabeth Sanchez', 1),
#  ('Karen Yang', 2),
#  ('Elizabeth Keller', 2),
#  ('Carl Cardenas', 1),
#  ('Erik Suarez', 1),
#  ('Brian Castaneda', 1),
#  ('Laura Schneider', 1),
#  ('Jeremy Baker', 1),
#  ('Michael Hale', 1),
#  ('Richard Suarez', 2),
#  ('Angela Moore', 1),
#  ('Juan Black', 4),
#  ('Amy Chang', 2),
#  ('Tammy Petersen', 1),
#  ('Kathryn Adams', 1),
#  ('Donald Taylor', 1),
#  ('Michele Price', 1),
#  ('Paul Lee', 1),
#  ('Kevin Hensley', 1),
#  ('Christina Harper', 2),
#  ('Carol Owen', 2),
#  ('Lisa Bennett', 1),
#  ('Gabrielle Miranda', 1),
#  ('Emily Dunn', 1),
#  ('Yvonne Lynn', 3),
#  ('Emily Anderson', 2),
#  ('Tyler Ortega', 1),
#  ('Patrick Cobb', 1),
#  ('Kimberly Marshall', 3),
#  ('Samuel Murray', 1),
#  ('Rachel Randolph', 2),
#  ('Mark Martinez', 2),
#  ('Jordan Kelly', 1),
#  ('Brian Hanson', 1),
#  ('Sarah Taylor', 1),
#  ('Danielle Graham', 2),
#  ('Jacob Eaton', 2),
#  ('Taylor Rodriguez', 3),
#  ('Michelle Barnett', 1),
#  ('Justin Perez', 1),
#  ('Steven Henry', 3),
#  ('Amanda Dennis', 1),
#  ('Victoria Reed', 2),
#  ('Alfred Elliott', 1),
#  ('Kathleen Lynch', 2),
#  ('Joseph Rivera', 3),
#  ('Jessica Kemp', 3),
#  ('Tony Beck', 3),
#  ('Lindsay Phelps', 1),
#  ('Michael Cook', 1),
#  ('Tristan Bird', 1),
#  ('Anthony Santos', 1),
#  ('Christopher Miller', 1),
#  ('Amber Spencer', 1),
#  ('Brandon Tran', 1),
#  ('Yolanda Whitehead', 2),
#  ('Riley Davies', 3),
#  ('James Lindsey', 1),
#  ('Justin Murphy', 3),
#  ('Robert Mullins', 1),
#  ('Clinton Palmer', 1),
#  ('David Brown', 1),
#  ('Michael Gutierrez', 1),
#  ('Andrea Taylor', 1),
#  ('Elizabeth Robertson', 2),
#  ('Benjamin Weaver', 2),
#  ('Adam Richardson', 2),
#  ('Victor Norris', 1),
#  ('Melissa Buckley', 1),
#  ('Veronica Coleman', 2),
#  ('Meagan Martinez', 2),
#  ('Donald Mitchell', 1),
#  ('Joy Hodges', 1),
#  ('Samantha Thompson', 1),
#  ('Christopher Brown Jr.', 1),
#  ('David Wright', 1),
#  ('Justin Hall', 3),
#  ('Nicole Carter', 3),
#  ('Carlos Dean', 1),
#  ('Gregory Dillon', 1),
#  ('Yvonne Jones', 1),
#  ('Patricia Martin', 1),
#  ('Dr. Don Hall', 1),
#  ('Judy Chavez', 1),
#  ('Richard Brown', 1),
#  ('David Rhodes', 1),
#  ('Sara Lopez', 1),
#  ('Amanda Harrell', 2),
#  ('Jill May', 2),
#  ('Emily Mccullough', 1),
#  ('Krista Castro', 2),
#  ('Shannon Martin', 1),
#  ('Leslie Martin', 1),
#  ('Christina Hernandez', 1),
#  ('Jeffrey Martin', 1),
#  ('Vanessa Lin', 1),
#  ('Elizabeth Griffin', 4),
#  ('Nathan Ross', 1),
#  ('Chase Estrada', 1),
#  ('Willie Maldonado', 1),
#  ('Anthony Hart', 2),
#  ('Allison Rodriguez', 1),
#  ('Dylan Mathis', 1),
#  ('Maria Alvarez', 2),
#  ('Andrew Howard', 1),
#  ('David Gates', 1),
#  ('Christopher Martinez', 1),
#  ('Mark Williams', 3),
#  ('Eric White', 2),
#  ('Justin Bell', 1),
#  ('Edwin Sims', 2),
#  ('Sheri Nixon', 2),
#  ('Shane Garcia', 1),
#  ('Tricia Butler', 1),
#  ('Alexis Clarke', 1),
#  ('Deborah Sexton', 2),
#  ('Craig Moore', 1),
#  ('Breanna Steele', 1),
#  ('Kevin Ward', 2),
#  ('Lisa Jones', 4),
#  ('Matthew Scott', 2),
#  ('Brian Harrison', 1),
#  ('Amanda Sanders', 1),
#  ('Holly Martin', 3),
#  ('Jennifer Bell', 1),
#  ('Deborah Shields', 1),
#  ('Tina Jones', 1),
#  ('James Hernandez', 1),
#  ('Kimberly Jones', 1),
#  ('Robert Taylor', 2),
#  ('Angela Williams', 1),
#  ('Mark Allison', 2),
#  ('Tammy Hall', 1),
#  ('Christopher Cordova', 3),
#  ('Marvin Allen', 1),
#  ('Angela Stark', 2),
#  ('Dana Owens', 4),
#  ('Christian Oneill', 1),
#  ('Cindy Rogers', 1),
#  ('Gary Martinez', 2),
#  ('Justin Parker', 1),
#  ('Kristin Nguyen', 1),
#  ('Michelle Marks', 2),
#  ('Linda Pratt', 1),
#  ('Teresa Valdez', 3),
#  ('Christopher Jones', 1),
#  ('Kevin Deleon', 3),
#  ('Eddie Mitchell', 2),
#  ('Dr. James Smith DDS', 3),
#  ('Dawn Collins', 2),
#  ('Robin Scott', 1),
#  ('Brian Benson', 1),
#  ('Mary Baker', 1),
#  ('Juan Hernandez', 1),
#  ('Aaron Fox', 2),
#  ('Peggy Dorsey', 3),
#  ('Steven Black', 1),
#  ('Eric Brown', 2),
#  ('Veronica Alvarez', 1),
#  ('Andrew White', 2),
#  ('Christian Downs', 1),
#  ('Gary Leblanc', 2),
#  ('Jennifer Carroll', 2),
#  ('Carrie Hill', 1),
#  ('James Harrison', 1),
#  ('Cheyenne Jones', 1),
#  ('Alexander Tucker', 1),
#  ('Natalie Hoffman DVM', 1),
#  ('Paul Adams', 2),
#  ('Ashley Figueroa', 1),
#  ('Jennifer Reynolds', 2),
#  ('Haley Brown', 1),
#  ('Joshua Harris', 2),
#  ('Jon Arias', 3),
#  ('Barbara Murphy', 2),
#  ('Brian Perez', 1),
#  ('Daniel Newman', 2),
#  ('Crystal Carey', 1),
#  ('Lee Anderson', 3),
#  ('Isabella Diaz', 2),
#  ('Mitchell Walsh', 1),
#  ('David Mills', 2),
#  ('Robert Nielsen', 2),
#  ('Robert Hall', 3),
#  ('Samuel Huynh', 1),
#  ('Teresa Phillips', 2),
#  ('Tina Barrett', 2),
#  ('Hannah Robles', 2),
#  ('James Wallace', 3),
#  ('Joseph Powell', 2),
#  ('Gregory Stein', 2),
#  ('Laura Davis', 2),
#  ('Bradley Walls', 1),
#  ('Maria Daniel', 1),
#  ('Jamie Gilmore', 1),
#  ('Melissa Sosa', 1),
#  ('Matthew Thomas', 1),
#  ('Phillip George', 2),
#  ('Joseph Sanchez', 1),
#  ('Mr. Mitchell Rogers', 1),
#  ('Theresa Gibson', 1),
#  ('Aaron Davies', 1),
#  ('Mary Jensen', 1),
#  ('Katherine Turner', 2),
#  ('Michael Rose', 2),
#  ('Tonya Boyd', 2),
#  ('Cameron Bell', 4),
#  ('Kaitlyn Love', 3),
#  ('Misty King', 1),
#  ('Timothy Waters', 2),
#  ('Troy Chavez', 1),
#  ('Tina Tucker', 2),
#  ('Jennifer Johnson', 1),
#  ('Barry Dunn', 2),
#  ('Anthony Lopez', 1),
#  ('David Washington', 1),
#  ('Valerie Meyer DDS', 1),
#  ('Sarah Jones', 1),
#  ('Jacob Howell', 1),
#  ('Zachary Reed', 2),
#  ('Terry Blackburn', 1),
#  ('Austin Herrera', 1),
#  ('Julia Holland', 1),
#  ('Rachel Jackson', 1),
#  ('Larry White', 1),
#  ('Michael Hester', 2),
#  ('Ashley Guzman', 2),
#  ('Misty Coleman DDS', 1),
#  ('Patrick Garcia', 3),
#  ('Samantha West', 1),
#  ('Kevin Gibson', 1),
#  ('Jenny Lewis', 2),
#  ('Maria Bryant', 2),
#  ('Patrick Martinez', 3),
#  ('Nancy Long', 1),
#  ('Zachary Cruz', 1),
#  ('Daniel Ryan', 1),
#  ('Anna Salazar', 2),
#  ('Daniel Moyer', 2),
#  ('Nathan Roberson', 2),
#  ('Samantha Lopez', 1),
#  ('Collin Smith', 2),
#  ('Christian Burns', 1),
#  ('Wayne Davidson', 2),
#  ('Lori Flores', 2),
#  ('Rachel Fitzgerald', 1),
#  ('Kathryn Thomas', 1),
#  ('Jeanette Duncan', 1),
#  ('Katherine Duncan', 2),
#  ('Natalie Davis', 2),
#  ('Alejandro Contreras', 2),
#  ('Kevin Sanchez', 3),
#  ('Deanna Nguyen', 3),
#  ('Melvin Brown', 2),
#  ('Deborah Dean', 1),
#  ('Vincent Hodges', 3),
#  ('Stacie Burton', 3),
#  ('April Hughes', 1),
#  ('Tiffany Clark', 1),
#  ('Jacqueline Mendoza', 1),
#  ('Dalton Moore', 1),
#  ('Joseph Stone', 2),
#  ('Jonathan Horton Jr.', 1),
#  ('Stephanie Stewart', 2),
#  ('Kathleen Gill', 1),
#  ('Michael Garrison', 1),
#  ('Mitchell Cruz', 2),
#  ('Charles Walker', 1),
#  ('Nicole Lewis DDS', 1),
#  ('Annette Floyd', 3),
#  ('Wendy Jenkins', 1),
#  ('Darius Forbes', 1),
#  ('Christine Ramos', 2),
#  ('Roberta Thompson', 1),
#  ('Angela Castaneda', 1),
#  ('Kayla Williams', 1),
#  ('Nicholas Romero', 3),
#  ('Brian Compton', 2),
#  ('Steven Patterson', 2),
#  ('Sandra Singleton', 1),
#  ('Jacqueline Johnson', 1),
#  ('Ellen Wise', 1),
#  ('Hannah Davis', 1),
#  ('Samantha Jackson', 2),
#  ('Mary Armstrong', 3),
#  ('Amanda Burnett', 2),
#  ('Daniel Lane', 1),
#  ('Joshua Jones', 1),
#  ('Lisa Perry', 1),
#  ('Gina Crawford', 2),
#  ('Brendan Allen', 1),
#  ('Douglas Phillips', 1),
#  ('Gary Hale', 1),
#  ('Jessica Navarro', 2),
#  ('Lynn Cunningham', 1),
#  ('Derek Boyer', 2),
#  ('Kimberly Griffin', 4),
#  ('Melissa Macias', 1),
#  ('Patricia Kim', 2),
#  ('Joseph Peterson', 2),
#  ('John Yoder', 2),
#  ('Christopher Larson', 1),
#  ('Vincent Callahan', 1),
#  ('Michael Black', 2),
#  ('Michael Hopkins', 1),
#  ('Taylor Nelson', 1),
#  ('Keith Harris', 1),
#  ('Matthew Mcclain', 1),
#  ('Pamela Ray', 1),
#  ('Thomas Quinn', 1),
#  ('Brent Ho', 2),
#  ('Bryan Mcfarland', 1),
#  ('Christina Parker', 1),
#  ('Wayne Leblanc', 1),
#  ('Theresa Evans', 1),
#  ('Kelly Williams', 2),
#  ('Stephanie Rivera', 1),
#  ('Antonio Peck', 1),
#  ('Cathy Taylor', 3),
#  ('Linda Hogan', 1),
#  ('Christina Freeman', 1),
#  ('Ashley Burns', 1),
#  ('Gina Cobb', 2),
#  ('Brett Alexander', 2),
#  ('Mark Paul', 3),
#  ('Ronald Lopez', 2),
#  ('Rebecca Graves', 2),
#  ('Emily Jones', 2),
#  ('Joseph Sullivan', 1),
#  ('Tracy Brooks', 1),
#  ('Jason Davis', 3),
#  ('Brittany Burton', 1),
#  ('Mark Wright', 2),
#  ('Christopher Smith', 2),
#  ('Joseph Campos', 1),
#  ('Kevin Russell', 1),
#  ('Marissa Kim', 1),
#  ('Jason Bush', 1),
#  ('Damon Barrett', 1),
#  ('Robert Nash', 2),
#  ('Shawn Harris', 1),
#  ('Kristy Blevins', 2),
#  ('Jennifer Lane', 2),
#  ('Matthew Cole', 3),
#  ('David Powell', 1),
#  ('Cassandra Jackson', 1),
#  ('Joseph Jackson', 2),
#  ('David Johnson', 1),
#  ('Melanie Johnson', 1),
#  ('Karen Baker', 1),
#  ('Teresa Nguyen', 1),
#  ('Sean Peterson', 2),
#  ('Ashley Doyle', 1),
#  ('Lori Boyd', 1),
#  ('Anthony Pacheco', 1),
#  ('Jonathan Butler', 1),
#  ('Kelly Wolf', 2),
#  ('Tyler Hunt', 1),
#  ('Misty Patel', 1),
#  ('Carmen Phillips', 1),
#  ('Jacob Gonzales', 1),
#  ('Carlos Cochran', 1),
#  ('Luis Davis', 1),
#  ('Alyssa Lozano', 3),
#  ('Matthew Gross', 2),
#  ('Mr. Fernando Lowe MD', 2),
#  ('John Cervantes', 3),
#  ('Brent Shields', 1),
#  ('Jonathan Jones', 2),
#  ('Carol Miranda', 1),
#  ('Robert Norman', 1),
#  ('Dale Santiago', 1),
#  ('Ryan Johnson', 1),
#  ('Joshua Guzman', 2),
#  ('Ann Campbell', 2),
#  ('Linda Ellison', 2),
#  ('Donald Jones', 1),
#  ('Allison White', 1),
#  ('Jonathan Montoya', 1),
#  ('Samantha Castro', 2),
#  ('Edward Williams', 1)]

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
